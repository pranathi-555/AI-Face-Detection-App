# %%
import cv2
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 5.0.0

# %%
import cv2

print("OpenCV Version:", cv2.__version__)
# Out:
# OpenCV Version: 5.0.0

# %%
import cv2
import matplotlib

print("cv2 module location:", cv2.__file__)
print("OpenCV version:", cv2.__version__)

print("Matplotlib version:", matplotlib.__version__)
# Out:
# cv2 module location: c:\Users\ADMIN\OneDrive\Desktop\AI PROJECTS\Face_Detection_App\venv\Lib\site-packages\cv2\__init__.py
# OpenCV version: 5.0.0
# Matplotlib version: 3.11.0

# %%
image = cv2.imread("test_images/fourppl.jpg")

# %%
print(image.shape)
# Out:
# (360, 558, 3)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(8,6))
plt.imshow(gray, cmap="gray")
plt.axis("off")
plt.show()

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 face_cascade = cv2.CascadeClassifier(
#       2     cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
#       3 )
#
# AttributeError: module 'cv2' has no attribute 'CascadeClassifier'

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 face_cascade = cv2.CascadeClassifier(
#       2     cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
#       3 )
#
# AttributeError: module 'cv2' has no attribute 'CascadeClassifier'

# %%
import cv2

print(cv2.__file__)
print(cv2.__version__)
print(hasattr(cv2, "CascadeClassifier"))
# Out:
# c:\Users\ADMIN\OneDrive\Desktop\AI PROJECTS\Face_Detection_App\venv\Lib\site-packages\cv2\__init__.py
# 5.0.0
# False

# %%
import cv2

print("Version:", cv2.__version__)
print("Cascade Exists:", hasattr(cv2, "CascadeClassifier"))
# Out:
# Version: 4.10.0
# Cascade Exists: True

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

print("Face detector loaded successfully!")
# Out:
# Face detector loaded successfully!

# %%
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

print("Number of faces detected:", len(faces))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 faces = face_cascade.detectMultiScale(
# ----> 2     gray,
#       3     scaleFactor=1.1,
#       4     minNeighbors=5,
#       5     minSize=(30, 30)
#
# NameError: name 'gray' is not defined

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("test_images/family.jpg")

# %%
image = cv2.imread("test_images/group.jpg")

# %%
print(image.shape)
# Out:
# (954, 1300, 3)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# %%
faces = face_cascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30)
)

print("Number of faces detected:", len(faces))
# Out:
# Number of faces detected: 10

# %%
output = image.copy()

for (x, y, w, h) in faces:
    cv2.rectangle(
        output,
        (x, y),
        (x + w, y + h),
        (0, 255, 0),   # Green color
        2              # Thickness
    )

print("Bounding boxes drawn successfully!")
# Out:
# Bounding boxes drawn successfully!

# %%
output_rgb = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8, 6))
plt.imshow(output_rgb)
plt.axis("off")
plt.title("Detected Faces")
plt.show()

# %%
cv2.imwrite("output_images/detected_faces.jpg", output)

print("Image saved successfully!")
# Out:
# Image saved successfully!
